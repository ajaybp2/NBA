# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaybp2/NBA/blob/main/NBA_STATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NBA DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; 
sns.set()

# %% [markdown]
# 1.) The reason I chose this dataset is because I am a huge basketball fan and am interested to see what I can find through data anlayses.

# %% [markdown]
# 2.)
#
# Does height play a major role in how many rebounds a player gets? D
#
# Are players from the 1st round more succesful than those chosen from the second round? D
#
# When was Lebrons best season based on ppg? D
#
# Average height of NBA players from the 2018-19 season? D
#
# What percentage of players from the 2018-19 season played at UIUC? D

# %%
df = pd.read_csv('https://github.com/ajaybp2/NBA/blob/main/all_seasons.csv?raw=true')

# %%
df.shape
# Out:
# (11145, 22)

# %%
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 11140       11140         Maxi Kleber               DAL  28.0         208.28
# 11141       11141  Melvin Frazier Jr.               ORL  23.0         195.58
# 11142       11142      Meyers Leonard               MIA  28.0         213.36
# 11143       11143        Norvel Pelle               PHI  27.0         208.28
# 11144       11144         Matt Thomas               TOR  25.0         193.04
#
#        player_weight     college  country draft_year draft_round  ...  pts  \
# 11140     108.862080        None  Germany  Undrafted   Undrafted  ...  9.1
# 11141      97.522280      Tulane      USA       2018           2  ...  1.2
# 11142     117.933920    Illinois      USA       2012           1  ...  6.1
# 11143     104.779752        None      USA  Undrafted   Undrafted  ...  2.1
# 11144      86.182480  Iowa State      USA  Undrafted   Undrafted  ...  4.5
#
# ...

# %%
df.sample(20)
# Out:
#        Unnamed: 0               player_name team_abbreviation   age  \
# 7483         7483           Darren Collison               DAL  25.0
# 1493         1493            Corey Benjamin               CHI  22.0
# 5327         5327             Ronald Dupree               SEA  27.0
# 8003         8003                Melvin Ely               NOP  36.0
# 10879       10879                Damion Lee               GSW  27.0
# 8480         8480               Travis Wear               NYK  24.0
# 5981         5981            DaJuan Summers               DET  22.0
# 5106         5106             Maurice Evans               ORL  29.0
# 3062         3062           Michael Stewart               CLE  28.0
# 9178         9178  Kentavious Caldwell-Pope               DET  24.0
# 3924         3924               Dwyane Wade               MIA  23.0
# 7287         7287               Tony Wroten               MEM  20.0
# 103           103             Greg Ostertag               UTA  24.0
# ...

# %%
df.sort_values('player_height')
# Out:
#       Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 401          401     Muggsy Bogues               CHH  32.0         160.02
# 1123        1123     Muggsy Bogues               GSW  34.0         160.02
# 2020        2020     Muggsy Bogues               TOR  36.0         160.02
# 483          483     Muggsy Bogues               GSW  33.0         160.02
# 1705        1705     Muggsy Bogues               TOR  35.0         160.02
# ...          ...               ...               ...   ...            ...
# 1053        1053     Shawn Bradley               DAL  27.0         228.60
# 647          647     Shawn Bradley               DAL  26.0         228.60
# 92            92  Gheorghe Muresan               WAS  26.0         231.14
# 1212        1212  Gheorghe Muresan               NJN  28.0         231.14
# 1408        1408  Gheorghe Muresan               NJN  29.0         231.14
#
#       player_weight        college country draft_year draft_round  ...   pts  \
# ...

# %%
df_Mugsy = df[df['player_name'] == 'Muggsy Bogues']
df_Mugsy['reb'].mean()
# Out:
# 1.8199999999999998

# %% [markdown]
# Shortest player to ever play in the NBA is Muggsy Bogues at 160 cm or 5 foot 2 inches who averaged 1.8 rebounds in his career

# %%
df[df['player_name'] =='LeBron James'].groupby(['player_name','pts', 'reb', 'ast', 'season']).mean()
# Out:
#                                     Unnamed: 0   age  player_height  \
# player_name  pts  reb ast  season
# LeBron James 20.9 5.5 5.9  2003-04        3120  19.0         203.20
#              25.3 6.0 7.4  2014-15        8322  30.0         203.20
#                   7.4 6.8  2015-16        8640  31.0         203.20
#              25.6 7.8 10.7 2019-20       11042  35.0         205.74
#              26.4 8.6 8.7  2016-17        9220  32.0         203.20
#              26.7 7.5 7.0  2010-11        6266  26.0         203.20
#              26.8 8.0 7.3  2012-13        7428  28.0         203.20
#              27.1 6.9 6.3  2013-14        7954  29.0         203.20
#                   7.9 6.2  2011-12        7004  27.0         203.20
#              27.2 7.4 7.2  2004-05        3617  20.0         203.20
#              27.3 6.7 6.0  2006-07        4778  22.0         203.20
#              27.4 8.5 8.3  2018-19       10520  34.0         203.20
# ...

# %% [markdown]
# LeBron James average the most points when he was 21 years old in the 2005-06 season

# %%
df_draft1 = df[df['draft_round'] == '1']
sns.displot(df_draft1['pts'], kde=True)
plt.xlabel('Points Scored')
plt.ylabel('Number of Players')
plt.title('Points Scored By Draft 1 Picks')

df_draft1 = df[df['draft_round'] == '1']
sns.displot(df_draft1['ast'], kde=True)
plt.xlabel('Assists')
plt.ylabel('Number of Players')
plt.title('Assists By Draft 1 Picks')

df_draft1 = df[df['draft_round'] == '1']
sns.displot(df_draft1['reb'], kde=True)
plt.xlabel('Rebounds')
plt.ylabel('Number of Players')
plt.title('Rebounds By Draft 1 Picks')
# Out:
# Text(0.5, 1.0, 'Rebounds By Draft 1 Picks')

# %%
df_draft2 = df[df['draft_round'] == '2']
sns.displot(df_draft2['pts'], kde=True)
plt.xlabel('Points Scored')
plt.ylabel('Number of Players')
plt.title('Points Scored By Draft 2 Picks')

df_draft2 = df[df['draft_round'] == '2']
sns.displot(df_draft2['ast'], kde=True)
plt.xlabel('Assists')
plt.ylabel('Number of Players')
plt.title('Assists By Draft 2 Picks')

df_draft2 = df[df['draft_round'] == '2']
sns.displot(df_draft2['reb'], kde=True)
plt.xlabel('Rebounds')
plt.ylabel('Number of Players')
plt.title('Rebounds By Draft 2 Picks')
# Out:
# Text(0.5, 1.0, 'Rebounds By Draft 2 Picks')

# %%
print('DRAFT 1:', 'points =', df_draft1['pts'].mean(), 'assists =', df_draft1['ast'].mean(), 'rebounds', df_draft1['reb'].mean())
print('-----------------------------------------------------------------------------------------')
print('DRAFT 2:', 'points =', df_draft2['pts'].mean(), 'assists =', df_draft2['ast'].mean(), 'rebounds', df_draft2['reb'].mean())
# Out:
# DRAFT 1: points = 9.96975280208813 assists = 2.135989559342853 rebounds 4.238384768923691
# -----------------------------------------------------------------------------------------
# DRAFT 2: points = 6.171129707112971 assists = 1.397109166983644 rebounds 2.8771776340814

# %%
df_draft1['pts'].mean()
# Out:
# 9.96975280208813

# %%
df_draft2['pts'].mean()
# Out:
# 6.171129707112971

# %%
df_2018 = df[df['season'] == '2018-19']

sns.boxplot(x = 'player_height', data = df_2018)
# Out:
# <AxesSubplot:xlabel='player_height'>

# %%
df['player_height'].mean()
df_above_avg = df[df['player_height'] > 200.81281830417225]
df_below_avg = df[df['player_height'] < 200.81281830417225]
print('avg height', df['player_height'].mean())
print('avg rebound for under height', df_below_avg['reb'].mean())
print('avg rebound for under height', df_above_avg['reb'].mean())
# Out:
# avg height 200.81281830417225
# avg rebound for under height 2.5678360479684983
# avg rebound for under height 4.557412738395106

# %%
sns.barplot(x = 'player_height', y = 'reb', data=df_above_avg)
# Out:
# <AxesSubplot:xlabel='player_height', ylabel='reb'>

# %%
sns.barplot(x = 'player_height', y = 'reb', data=df_below_avg)
# Out:
# <AxesSubplot:xlabel='player_height', ylabel='reb'>

# %%
sns.barplot(x = 'player_height', y = 'reb', data=df)
# Out:
# <AxesSubplot:xlabel='player_height', ylabel='reb'>

# %%
df_illinois = df_2018[df_2018['college'] == 'Illinois']
df_not_illinois = df_2018[df_2018['college'] != 'Illinois']

import matplotlib.pyplot as plt
import numpy as np
df_illinois.shape[0]
df_not_illinois.shape[0]

y = np.array([df_illinois.shape[0], df_not_illinois.shape[0]])
mylabels = ["Illinois", "Not Illinois"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
print('percent of players drafted from UIUC', df_illinois.shape[0] / df_not_illinois.shape[0])
# Out:
# percent of players drafted from UIUC 0.001890359168241966

# %%
df_lebron = df[df['player_name'] == 'LeBron James']
df_lebron.sort_values('age')
# Out:
#        Unnamed: 0   player_name team_abbreviation   age  player_height  \
# 3120         3120  LeBron James               CLE  19.0         203.20
# 3617         3617  LeBron James               CLE  20.0         203.20
# 4075         4075  LeBron James               CLE  21.0         203.20
# 4778         4778  LeBron James               CLE  22.0         203.20
# 5104         5104  LeBron James               CLE  23.0         203.20
# 5430         5430  LeBron James               CLE  24.0         203.20
# 6127         6127  LeBron James               CLE  25.0         203.20
# 6266         6266  LeBron James               MIA  26.0         203.20
# 7004         7004  LeBron James               MIA  27.0         203.20
# 7428         7428  LeBron James               MIA  28.0         203.20
# 7954         7954  LeBron James               MIA  29.0         203.20
# 8322         8322  LeBron James               CLE  30.0         203.20
# ...

# %%
plt.plot(df_lebron['age'], df_lebron['pts'], color='blue', marker='o')
plt.xlabel('Age')
plt.ylabel('Points Per Game')
plt.title('LeBron James PPG every season')
# Out:
# Text(0.5, 1.0, 'LeBron James PPG every season')

# %%
df_mj = df[df['player_name'] =='Michael Jordan']
df_mj
# Out:
#       Unnamed: 0     player_name team_abbreviation   age  player_height  \
# 392          392  Michael Jordan               CHI  34.0         198.12
# 467          467  Michael Jordan               CHI  35.0         198.12
# 2208        2208  Michael Jordan               WAS  39.0         198.12
# 3055        3055  Michael Jordan               WAS  40.0         198.12
#
#       player_weight         college country draft_year draft_round  ...   pts  \
# 392       97.975872  North Carolina     USA       1984           1  ...  29.6
# 467       97.975872  North Carolina     USA       1984           1  ...  28.7
# 2208      97.975872  North Carolina     USA       1984           1  ...  22.9
# 3055      97.975872  North Carolina     USA       1984           1  ...  20.0
#
#       reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# 392   5.9  4.3        13.4     0.042     0.132    0.331   0.567    0.208
# ...

# %% [markdown]
#     From the data analysis I was able to answer the questions proposed at the beginning of the project. I have found that height does play a major role in the amount of rebounds a NBA player gets. The average height for an NBA player is 200.8 cm. Players under that height on avearge grabbed 2.6 rebounds and players over that average grabbed 4.6 rebounds. This is an 80% increase in amounts of rebounds grabbed. The height where the most rebounds were grabbed is around 210 cm.
#
#     I was also able to find that players chosen in the 1sr round of the draft are on average become better players than those chosen in the 2nd round of the draft. Players that were chosen in the first round averaged 10 ppg, 2.1 apg, and 4.2 rpg. Whereas players chosen in the second draft average 6.2 ppg, 1.3 apg, and 2.9 rbp. Players in the first draft are better in every category by a reasonable amount.
#
#     LeBron James is deemed as one of the best players to play basketball (often compared to Micahel Jordan as the best player ever). I was curious to see when he averaged the most ppg. I found that he averaged the most points (31.4) in the 2005-2006 season when he was 21 years old. This is hard to beleive as it was only his 3rd year in the NBA.
#     The average height for NBA players from the 2018-19 season was higher than expected. The average height was 200.8 cm which is 6 feet and 7 inches tall.
#
#     To finalize, I was curious as to as how many people in the NBA in the most reason season were drafted from UIUC. I found that only 1 person drafted from UIUC currently plays in the NBA. That person is Meyers Leonard who was drafted in 2012, so only 0.00189% of current NBA players are in the NBA. It is also important to know that due to racist comments made by Meyer Leonards, he was waived by his team no longer on a NBA team currently.
